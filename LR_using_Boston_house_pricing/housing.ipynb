# %%
#importing important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data from the .csv file
df = pd.read_csv('housing.csv')

# %%
#Visvalizing the data to get the correlation between different parameters of the dataset
plt.figure()
sns.heatmap(df.corr(),cmap='coolwarm')
plt.show()

# %%
#Choosing Tax and Radius as the parameters to train the model
tax = df['TAX']
rad = df['RAD']

x = np.array(tax).reshape(-1,1)
y = np.array(rad)

# %%
#importing train_test_split to split the data for training and testing purpose
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

#importing Linear Regression Model from the scikit learn library
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
print(model.coef_)

pred = model.predict(x_test)
predictions = pred.reshape(-1,1)

#Ultimately determining the error in the Predictions made by the model against the true values
from sklearn.metrics import mean_squared_error
print('MSE : ',mean_squared_error(y_test,predictions))
print('RMSE : ',np.sqrt(mean_squared_error(y_test,predictions)))
# Out:
# [-9.18116541]
# [[0.04613012]]
# MSE :  12.474922171081845
# RMSE :  3.5319855847783193
